# %%
import sqlite3
import pandas as pd
import savantscraper

# Example for two years and two teams
savantscraper.database_import('baseball_savant_all',
                              (2018, 2018))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-527f33364036> in <module>
#       1 import sqlite3
# ----> 2 import pandas as pd
#       3 import savantscraper
#       4
#       5 # Example for two years and two teams
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Connect to the database
conn = sqlite3.connect('baseball_savant_all.db')

# Query the database and load into a pandas dataframe

df = pd.read_sql_query(
    "select player_name, launch_speed, launch_angle, events from statcast "
    "where events in ('single', 'double', 'triple', 'home_run', 'field_out');", conn)

# Close connection when finished
conn.close()

df
# Out:
#                 player_name  launch_speed  launch_angle     events
# 0           Parker Bridwell          61.0         -35.0  field_out
# 1           Parker Bridwell          93.5          61.0  field_out
# 2            Junichi Tazawa         100.8          10.0  field_out
# 3            Williams Jerez          52.4         -65.0  field_out
# 4            Williams Jerez          64.5           5.0  field_out
# 5       Odrisamer Despaigne         108.4          26.0   home_run
# 6       Odrisamer Despaigne         106.6          14.0     single
# 7       Odrisamer Despaigne          80.7           8.0  field_out
# 8       Odrisamer Despaigne          97.6          44.0  field_out
# 9       Odrisamer Despaigne          86.1         -12.0  field_out
# 10      Odrisamer Despaigne          85.4          29.0     double
# 11      Odrisamer Despaigne          86.8          38.0  field_out
# 12      Odrisamer Despaigne          96.5          35.0  field_out
# 13           Matt Shoemaker         100.8          23.0  field_out
# 14           Matt Shoemaker          87.1         -15.0  field_out
# 15           Matt Shoemaker          70.4          12.0     single
# 16           Matt Shoemaker          87.2          45.0  field_out
# 17           Matt Shoemaker         106.4          29.0   home_run
# 18           Matt Shoemaker          91.1          44.0  field_out
# 19           Matt Shoemaker          95.7          42.0  field_out
# 20           Matt Shoemaker          95.9          -8.0  field_out
# 21           Miguel Almonte          88.6          40.0  field_out
# 22           Miguel Almonte         108.5          21.0     double
# 23           Miguel Almonte          69.2           4.0  field_out
# 24            Cam Bedrosian          79.0          86.0  field_out
# 25            Cam Bedrosian          69.0         -36.0  field_out
# 26             Deck McGuire          88.5          14.0     single
# 27             Deck McGuire          74.3          -1.0  field_out
# 28              Jim Johnson         103.0          -3.0  field_out
# 29              Jim Johnson         100.0          28.0   home_run
# ...                     ...           ...           ...        ...
# 116161      Masahiro Tanaka          75.1          47.0  field_out
# 116162      Masahiro Tanaka          92.7          23.0  field_out
# 116163      Masahiro Tanaka          80.0          69.0  field_out
# 116164      Masahiro Tanaka          99.7          38.0  field_out
# 116165      Masahiro Tanaka          91.2          46.0  field_out
# 116166      Masahiro Tanaka          76.6         -23.0  field_out
# 116167      Masahiro Tanaka          96.6           1.0     double
# 116168      Masahiro Tanaka          84.7          -6.0  field_out
# 116169      Masahiro Tanaka         105.2          23.0   home_run
# 116170      Masahiro Tanaka          93.9          -6.0  field_out
# 116171      Masahiro Tanaka          80.0          69.0  field_out
# 116172      Masahiro Tanaka         100.3          23.0     double
# 116173      Masahiro Tanaka          89.2          39.0  field_out
# 116174      Aroldis Chapman          96.4          20.0  field_out
# 116175      Dellin Betances          79.1          73.0  field_out
# 116176      Dellin Betances         104.4           7.0  field_out
# 116177      Dellin Betances          75.4           4.0  field_out
# 116178      Dellin Betances         104.0          32.0   home_run
# 116179           Chad Green          73.7         -59.0  field_out
# 116180        Luis Severino          48.3          -9.0  field_out
# 116181        Luis Severino          80.0          69.0  field_out
# 116182        Luis Severino          67.4          -7.0  field_out
# 116183        Luis Severino          95.9          28.0  field_out
# 116184        Luis Severino         100.4          13.0     single
# 116185        Luis Severino          91.5         -31.0  field_out
# 116186        Luis Severino          83.7         -35.0  field_out
# 116187        Luis Severino          82.0         -31.0  field_out
# 116188        Luis Severino          97.7          -9.0  field_out
# 116189        Luis Severino         103.6          40.0  field_out
# 116190        Luis Severino          51.9          -4.0  field_out
#
# [116191 rows x 4 columns]

# %%
df.to_pickle('statcast_data.pkl')
